# %%
import pandas as pd

# %%
import json

# %%
df = pd.read_json("C:\\Users\\emily\\OneDrive\\Desktop\\Data Science Bootcamp\\wk4\\LHL-Project-3\\drive-download-20230205T225545Z-001\\weekly_earnings.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39232\1567797932.py in <module>
# ----> 1 df = pd.read_json("C:\\Users\\emily\\OneDrive\\Desktop\\Data Science Bootcamp\\wk4\\LHL-Project-3\\drive-download-20230205T225545Z-001\\weekly_earnings.json")
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv("csv_maybe.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39232\3174709231.py in <module>
# ----> 1 df = pd.read_csv("csv_maybe.csv")
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_json("weekly_earnings_mod.json")

# %%
df
# Out:
#                                                   data
# 0    [5554, 8D0D0120-53D5-4A3D-B68F-D5BAFA1B9F24, 5...
# 1    [5555, B8156EED-2420-4B71-A56C-57DED1FA7CEC, 5...
# 2    [5556, A8D7795E-40FA-4923-AB52-CA8536DAAD7A, 5...
# 3    [5557, 8373DAD3-2886-4DAD-AFE8-84DB8C0F414E, 5...
# 4    [5558, 05DB3E97-35EC-4F75-891B-3F6C696CDEE0, 5...
# ..                                                 ...
# 167  [5721, 929B44CE-29DA-42D8-B7C3-C87C70D4C383, 5...
# 168  [5722, F8CF4AB6-378A-4075-8BE7-6195EE417848, 5...
# 169  [5723, F7A31164-A7FE-467F-A9F7-8A06954FB391, 5...
# 170  [5724, 58A68982-BF09-4DA2-9C86-094D9F52BB8F, 5...
# 171  [5725, 21789CE9-CD5C-4B1F-BAFF-B3D7C45E6F25, 5...
#
# [172 rows x 1 columns]

# %%
df2 = pd.read_json("weekly_earnings_mod2.json")
df2.columns = ["sid", "id", "position", "created_at", "created_meta", "updated_at", "updated_meta", "meta", 
"When", "NAICS", "Alberta", "British_Columbia", "Canada", "Manitoba", "New_Brunswick", "Newfoundland_And_Labrador", 
"Nova_Scotia", "Ontario", "Prince_Edward_Island", "Quebec", "Saskatchewan"]
df2.head()
# Out:
#     sid                                    id  position  created_at  \
# 0  5554  8D0D0120-53D5-4A3D-B68F-D5BAFA1B9F24      5554  1435599444
# 1  5555  B8156EED-2420-4B71-A56C-57DED1FA7CEC      5555  1435599444
# 2  5556  A8D7795E-40FA-4923-AB52-CA8536DAAD7A      5556  1435599444
# 3  5557  8373DAD3-2886-4DAD-AFE8-84DB8C0F414E      5557  1435599444
# 4  5558  05DB3E97-35EC-4F75-891B-3F6C696CDEE0      5558  1435599444
#
#    created_meta  updated_at  updated_meta  meta                 When  \
# 0        710753  1435599444        710753   NaN  2001-01-01T00:00:00
# 1        710753  1435599444        710753   NaN  2001-02-01T00:00:00
# 2        710753  1435599444        710753   NaN  2001-03-01T00:00:00
# 3        710753  1435599444        710753   NaN  2001-04-01T00:00:00
# 4        710753  1435599444        710753   NaN  2001-05-01T00:00:00
#
#                                                NAICS  ...  British_Columbia  \
# ...

# %%
df2 = df2.drop("position", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39232\3980279957.py in <module>
# ----> 1 df2 = df2.drop("position", axis=1)
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# c:\Users\emily\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df2 = df2.drop(["id", "created_at", "created_meta", "updated_at", "updated_meta", "meta"], axis=1)

df2.head()
# Out:
#     sid                 When  \
# 0  5554  2001-01-01T00:00:00
# 1  5555  2001-02-01T00:00:00
# 2  5556  2001-03-01T00:00:00
# 3  5557  2001-04-01T00:00:00
# 4  5558  2001-05-01T00:00:00
#
#                                                NAICS  Alberta  \
# 0  Industrial aggregate excluding unclassified bu...   670.54
# 1  Industrial aggregate excluding unclassified bu...   670.52
# 2  Industrial aggregate excluding unclassified bu...   668.49
# 3  Industrial aggregate excluding unclassified bu...   671.71
# 4  Industrial aggregate excluding unclassified bu...   664.45
#
#    British_Columbia  Canada  Manitoba  New_Brunswick  \
# 0            660.48  658.02    578.95         584.75
# 1            659.33  655.79    580.63         585.11
# 2            654.07  655.88    578.67         584.13
# 3            657.15  654.09    576.36         580.92
# 4            653.23  650.02    571.84         578.44
#
#    Newfoundland_And_Labrador  Nova_Scotia  Ontario  Prince_Edward_Island  \
# ...

# %%
df2.to_csv("C:\\Users\\emily\\OneDrive\\Desktop\\earnings_df.csv", index=False)
